# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
dataFrame = pd.read_csv("HousePriceData.csv")

# %%
dataFrame.head(20)
# Out:
#                    date      price  bedrooms  bathrooms  sqft_living  \
# 0   2014-05-02 00:00:00   313000.0       3.0       1.50         1340
# 1   2014-05-02 00:00:00  2384000.0       5.0       2.50         3650
# 2   2014-05-02 00:00:00   342000.0       3.0       2.00         1930
# 3   2014-05-02 00:00:00   420000.0       3.0       2.25         2000
# 4   2014-05-02 00:00:00   550000.0       4.0       2.50         1940
# 5   2014-05-02 00:00:00   490000.0       2.0       1.00          880
# 6   2014-05-02 00:00:00   335000.0       2.0       2.00         1350
# 7   2014-05-02 00:00:00   482000.0       4.0       2.50         2710
# 8   2014-05-02 00:00:00   452500.0       3.0       2.50         2430
# 9   2014-05-02 00:00:00   640000.0       4.0       2.00         1520
# 10  2014-05-02 00:00:00   463000.0       3.0       1.75         1710
# 11  2014-05-02 00:00:00  1400000.0       4.0       2.50         2920
# 12  2014-05-02 00:00:00   588500.0       3.0       1.75         2330
# ...

# %%
dataFrame.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
dataFrame.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
plt.figure(figsize=(15,8))
sbn.distplot(dataFrame["price"])
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
plt.figure(figsize=(60,8))
sbn.countplot(dataFrame["yr_built"])
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='yr_built', ylabel='count'>

# %%
dataFrame.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.200336   0.327110     0.430410  0.050451  0.151461
# bedrooms       0.200336  1.000000   0.545920     0.594884  0.068819  0.177895
# bathrooms      0.327110  0.545920   1.000000     0.761154  0.107837  0.486428
# sqft_living    0.430410  0.594884   0.761154     1.000000  0.210538  0.344850
# sqft_lot       0.050451  0.068819   0.107837     0.210538  1.000000  0.003750
# floors         0.151461  0.177895   0.486428     0.344850  0.003750  1.000000
# waterfront     0.135648 -0.003483   0.076232     0.117616  0.017241  0.022024
# view           0.228504  0.111028   0.211960     0.311009  0.073907  0.031211
# condition      0.034915  0.025080  -0.119994    -0.062826  0.000558 -0.275013
# sqft_above     0.367570  0.484705   0.689918     0.876443  0.216455  0.522814
# sqft_basement  0.210427  0.334165   0.298020     0.447206  0.034842 -0.255510
# ...

# %%
dataFrame.corr()["price"].sort_values()
# Out:
# yr_renovated    -0.028774
# yr_built         0.021857
# condition        0.034915
# sqft_lot         0.050451
# waterfront       0.135648
# floors           0.151461
# bedrooms         0.200336
# sqft_basement    0.210427
# view             0.228504
# bathrooms        0.327110
# sqft_above       0.367570
# sqft_living      0.430410
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(15,8))
sbn.scatterplot(x="yr_built",y="price",data=dataFrame)
# Out:
# <AxesSubplot:xlabel='yr_built', ylabel='price'>

# %%
dataFrame.sort_values("price",ascending = False).head(60)
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 4350  2014-07-03 00:00:00  2.659000e+07       3.0       2.00         1180
# 4346  2014-06-23 00:00:00  1.289900e+07       3.0       2.50         2190
# 2286  2014-06-11 00:00:00  7.062500e+06       5.0       4.50        10040
# 2654  2014-06-17 00:00:00  4.668000e+06       5.0       6.75         9640
# 2761  2014-06-18 00:00:00  4.489000e+06       4.0       3.00         6430
# 3729  2014-07-01 00:00:00  3.800000e+06       5.0       5.50         7050
# 1637  2014-05-30 00:00:00  3.710000e+06       4.0       3.50         5550
# 252   2014-05-07 00:00:00  3.200000e+06       7.0       4.50         6210
# 1567  2014-05-29 00:00:00  3.100000e+06       6.0       4.25         6980
# 2772  2014-06-18 00:00:00  3.000000e+06       4.0       4.25         4850
# 2328  2014-06-11 00:00:00  2.888000e+06       5.0       6.25         8670
# 1571  2014-05-29 00:00:00  2.750000e+06       4.0       3.25         4430
# ...

# %%
dataFrame.sort_values("price",ascending = True).head(60)
# Out:
#                      date     price  bedrooms  bathrooms  sqft_living  \
# 4472  2014-06-09 00:00:00       0.0       4.0       3.75         4060
# 4542  2014-06-25 00:00:00       0.0       5.0       3.50         2640
# 4481  2014-06-11 00:00:00       0.0       5.0       2.75         3240
# 4408  2014-05-21 00:00:00       0.0       5.0       2.25         2880
# 4411  2014-05-22 00:00:00       0.0       5.0       2.25         2000
# 4534  2014-06-24 00:00:00       0.0       3.0       2.75         1310
# 4412  2014-05-22 00:00:00       0.0       3.0       3.00         1860
# 4413  2014-05-22 00:00:00       0.0       4.0       3.00         1990
# 4528  2014-06-24 00:00:00       0.0       4.0       5.00         4550
# 4420  2014-05-27 00:00:00       0.0       4.0       1.00         1360
# 4523  2014-06-23 00:00:00       0.0       3.0       4.50         5230
# 4522  2014-06-22 00:00:00       0.0       2.0       2.25         1490
# ...

# %%
dataFrame["price"]
# Out:
# 0       3.130000e+05
# 1       2.384000e+06
# 2       3.420000e+05
# 3       4.200000e+05
# 4       5.500000e+05
#             ...
# 4595    3.081667e+05
# 4596    5.343333e+05
# 4597    4.169042e+05
# 4598    2.034000e+05
# 4599    2.206000e+05
# Name: price, Length: 4600, dtype: float64

# %%
dataFrame["price"] = dataFrame["price"].astype(int) 
# Datamdaki price sutundaki sayiların tamami tam sayi olmasına ragmen floatti bu yuzden veri karmasik gozukuyordu.
# Price sutunundaki sayilarin tamamini tam sayiya cevirdim.

# %%
dataFrame["price"]
# Out:
# 0        313000
# 1       2384000
# 2        342000
# 3        420000
# 4        550000
#          ...
# 4595     308166
# 4596     534333
# 4597     416904
# 4598     203400
# 4599     220600
# Name: price, Length: 4600, dtype: int32

# %%
dataFrame.sort_values("price",ascending = False).head(60)
# Out:
#                      date     price  bedrooms  bathrooms  sqft_living  \
# 4350  2014-07-03 00:00:00  26590000       3.0       2.00         1180
# 4346  2014-06-23 00:00:00  12899000       3.0       2.50         2190
# 2286  2014-06-11 00:00:00   7062500       5.0       4.50        10040
# 2654  2014-06-17 00:00:00   4668000       5.0       6.75         9640
# 2761  2014-06-18 00:00:00   4489000       4.0       3.00         6430
# 3729  2014-07-01 00:00:00   3800000       5.0       5.50         7050
# 1637  2014-05-30 00:00:00   3710000       4.0       3.50         5550
# 252   2014-05-07 00:00:00   3200000       7.0       4.50         6210
# 1567  2014-05-29 00:00:00   3100000       6.0       4.25         6980
# 2772  2014-06-18 00:00:00   3000000       4.0       4.25         4850
# 2328  2014-06-11 00:00:00   2888000       5.0       6.25         8670
# 1571  2014-05-29 00:00:00   2750000       4.0       3.25         4430
# ...

# %%
len(dataFrame)
# Out:
# 4600

# %%
dataFrame1 = dataFrame.sort_values("price",ascending = True).iloc[50:4550] # en dusuk fiyali 50, en yuksek fiyatli 50 evi attim

# %%
dataFrame1.sort_values("price",ascending = True)
# Out:
#                      date    price  bedrooms  bathrooms  sqft_living  \
# 1219  2014-05-23 00:00:00    80000       1.0       0.75          430
# 1587  2014-05-29 00:00:00    83000       2.0       1.00          900
# 4407  2014-05-20 00:00:00    83300       3.0       2.00         1490
# 4415  2014-05-23 00:00:00    83300       3.0       2.00         1370
# 4345  2014-06-01 00:00:00    84350       4.0       2.00         2630
# ...                   ...      ...       ...        ...          ...
# 2607  2014-06-16 00:00:00  1920000       4.0       2.50         3070
# 3661  2014-06-30 00:00:00  1925000       5.0       4.25         4830
# 2917  2014-06-20 00:00:00  1950000       7.0       3.50         4640
# 1690  2014-06-02 00:00:00  1965221       4.0       3.50         4370
# 1500  2014-05-28 00:00:00  1970000       8.0       3.50         4440
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 1219      5050     1.0           0     0          2         430
# ...

# %%
dataFrame1.sort_values("price",ascending = False)
# Out:
#                      date    price  bedrooms  bathrooms  sqft_living  \
# 1500  2014-05-28 00:00:00  1970000       8.0       3.50         4440
# 1690  2014-06-02 00:00:00  1965221       4.0       3.50         4370
# 2917  2014-06-20 00:00:00  1950000       7.0       3.50         4640
# 3661  2014-06-30 00:00:00  1925000       5.0       4.25         4830
# 2607  2014-06-16 00:00:00  1920000       4.0       2.50         3070
# ...                   ...      ...       ...        ...          ...
# 4345  2014-06-01 00:00:00    84350       4.0       2.00         2630
# 4407  2014-05-20 00:00:00    83300       3.0       2.00         1490
# 4415  2014-05-23 00:00:00    83300       3.0       2.00         1370
# 1587  2014-05-29 00:00:00    83000       2.0       1.00          900
# 1219  2014-05-23 00:00:00    80000       1.0       0.75          430
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 1500      6480     2.0           0     3          5        3140
# ...

# %%
len(dataFrame1)
# Out:
# 4500

# %%
plt.figure(figsize = (15,8))
sbn.distplot(dataFrame1["price"])
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
dataFrame1.describe()
# Out:
#               price     bedrooms    bathrooms  sqft_living      sqft_lot  \
# count  4.500000e+03  4500.000000  4500.000000  4500.000000  4.500000e+03
# mean   5.275097e+05     3.383333     2.137056  2100.678000  1.473529e+04
# std    2.875947e+05     0.896729     0.746933   881.612539  3.584344e+04
# min    8.000000e+04     0.000000     0.000000   370.000000  6.380000e+02
# 25%    3.250000e+05     3.000000     1.750000  1460.000000  5.000000e+03
# 50%    4.609430e+05     3.000000     2.250000  1960.000000  7.641000e+03
# 75%    6.500000e+05     4.000000     2.500000  2590.000000  1.085650e+04
# max    1.970000e+06     9.000000     5.750000  7320.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4500.000000  4500.000000  4500.000000  4500.000000  4500.000000
# mean      1.508667     0.004667     0.218222     3.448444  1798.883556
# std       0.537680     0.068161     0.732764     0.672225   812.914469
# ...

# %%
dataFrame1.groupby("yr_built").mean()["price"]
# Out:
# yr_built
# 1900    701045.454545
# 1901    506127.222222
# 1902    728583.333333
# 1903    513010.000000
# 1904    501933.333333
#             ...
# 2010    514751.296296
# 2011    452205.541667
# 2012    496441.636364
# 2013    651805.277778
# 2014    584991.818182
# Name: price, Length: 115, dtype: float64

# %%
dataFrame1.head()
# Out:
#                      date  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 1219  2014-05-23 00:00:00  80000       1.0       0.75          430      5050
# 1587  2014-05-29 00:00:00  83000       2.0       1.00          900      8580
# 4407  2014-05-20 00:00:00  83300       3.0       2.00         1490      7770
# 4415  2014-05-23 00:00:00  83300       3.0       2.00         1370     78408
# 4345  2014-06-01 00:00:00  84350       4.0       2.00         2630     16475
#
#       floors  waterfront  view  condition  sqft_above  sqft_basement  \
# 1219     1.0           0     0          2         430              0
# 1587     1.0           0     0          3         900              0
# 4407     1.0           0     0          4        1490              0
# 4415     1.0           0     0          5        1370              0
# 4345     2.0           0     0          4        2630              0
#
#       yr_built  yr_renovated                 street          city  statezip  \
# ...

# %%
dataFrame1 = dataFrame1.drop("date",axis = 1)

# %%
dataFrame1 = dataFrame1.drop("street",axis = 1)

# %%
dataFrame1 = dataFrame1.drop("city",axis = 1)

# %%
dataFrame1 = dataFrame1.drop("statezip",axis = 1)

# %%
dataFrame1 = dataFrame1.drop("country",axis = 1)

# %%
dataFrame1.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 1219  80000       1.0       0.75          430      5050     1.0           0
# 1587  83000       2.0       1.00          900      8580     1.0           0
# 4407  83300       3.0       2.00         1490      7770     1.0           0
# 4415  83300       3.0       2.00         1370     78408     1.0           0
# 4345  84350       4.0       2.00         2630     16475     2.0           0
#
#       view  condition  sqft_above  sqft_basement  yr_built  yr_renovated
# 1219     0          2         430              0      1912             0
# 1587     0          3         900              0      1918             0
# 4407     0          4        1490              0      1990             0
# 4415     0          5        1370              0      1964             0
# 4345     0          4        2630              0      1953          1983

# %%
y = dataFrame1["price"].values
x = dataFrame1.drop("price",axis = 1).values

# %%
y
# Out:
# array([  80000,   83000,   83300, ..., 1950000, 1965221, 1970000])

# %%
x
# Out:
# array([[1.000e+00, 7.500e-01, 4.300e+02, ..., 0.000e+00, 1.912e+03,
#         0.000e+00],
#        [2.000e+00, 1.000e+00, 9.000e+02, ..., 0.000e+00, 1.918e+03,
#         0.000e+00],
#        [3.000e+00, 2.000e+00, 1.490e+03, ..., 0.000e+00, 1.990e+03,
#         0.000e+00],
#        ...,
#        [7.000e+00, 3.500e+00, 4.640e+03, ..., 1.780e+03, 1.965e+03,
#         2.003e+03],
#        [4.000e+00, 3.500e+00, 4.370e+03, ..., 7.600e+02, 2.003e+03,
#         0.000e+00],
#        [8.000e+00, 3.500e+00, 4.440e+03, ..., 1.300e+03, 1.959e+03,
#         0.000e+00]])

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.3,random_state=10)

# %%
len(xtrain)
# Out:
# 3150

# %%
len(xtest)
# Out:
# 1350

# %%
len(ytrain)
# Out:
# 3150

# %%
len(ytest)
# Out:
# 1350

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
xtrain = scaler.fit_transform(xtrain)
xtest = scaler.transform(xtest)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
xtrain.shape
# Out:
# (3150, 12)

# %%
model = Sequential()

model.add(Dense(12,activation = "relu"))
model.add(Dense(12,activation = "relu"))
model.add(Dense(12,activation = "relu"))
model.add(Dense(12,activation = "relu"))
model.add(Dense(12,activation = "relu"))
model.add(Dense(12,activation = "relu"))
model.add(Dense(12,activation = "relu"))
model.add(Dense(12,activation = "relu"))

model.add(Dense(1))

model.compile(optimizer="adam",loss="mse")

# %%
model.fit(x=xtrain, y=ytrain, validation_data=(xtest,ytest), batch_size=250, epochs=300)
# Out:
# Epoch 1/300
# 13/13 [==============================] - 0s 10ms/step - loss: 366685618176.0000 - val_loss: 347596259328.0000
# Epoch 2/300
# 13/13 [==============================] - 0s 2ms/step - loss: 366685421568.0000 - val_loss: 347596161024.0000
# Epoch 3/300
# 13/13 [==============================] - 0s 3ms/step - loss: 366685356032.0000 - val_loss: 347595931648.0000
# Epoch 4/300
# 13/13 [==============================] - 0s 4ms/step - loss: 366684995584.0000 - val_loss: 347595472896.0000
# Epoch 5/300
# 13/13 [==============================] - 0s 3ms/step - loss: 366684209152.0000 - val_loss: 347594129408.0000
# Epoch 6/300
# 13/13 [==============================] - 0s 3ms/step - loss: 366681980928.0000 - val_loss: 347590393856.0000
# Epoch 7/300
# 13/13 [==============================] - 0s 3ms/step - loss: 366675689472.0000 - val_loss: 347580366848.0000
# Epoch 8/300
# ...

# %%
kayipVerisi = pd.DataFrame(model.history.history)

# %%
kayipVerisi.head()
# Out:
#            loss      val_loss
# 0  3.666856e+11  3.475963e+11
# 1  3.666854e+11  3.475962e+11
# 2  3.666854e+11  3.475959e+11
# 3  3.666850e+11  3.475955e+11
# 4  3.666842e+11  3.475941e+11

# %%
kayipVerisi.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
tahminDizisi = model.predict(xtest)

# %%
tahminDizisi
# Out:
# array([[1201447.1 ],
#        [ 558040.44],
#        [ 675205.7 ],
#        ...,
#        [ 244918.19],
#        [ 309107.  ],
#        [ 951083.1 ]], dtype=float32)

# %%
mean_absolute_error(ytest,tahminDizisi)
# Out:
# 137949.84537037037

# %%
dataFrame.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609430e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
plt.scatter(ytest,tahminDizisi)
plt.plot(ytest,ytest,"g-*")

# %%
dataFrame1.iloc[2000]
# Out:
# price            433000.0
# bedrooms              4.0
# bathrooms             2.5
# sqft_living        2280.0
# sqft_lot           7568.0
# floors                2.0
# waterfront            0.0
# view                  0.0
# condition             4.0
# sqft_above         2280.0
# sqft_basement         0.0
# yr_built           2001.0
# yr_renovated          0.0
# Name: 818, dtype: float64

# %%
yeniEv = dataFrame1.drop("price",axis=1).iloc[2000]

# %%
yeniEv
# Out:
# bedrooms            4.0
# bathrooms           2.5
# sqft_living      2280.0
# sqft_lot         7568.0
# floors              2.0
# waterfront          0.0
# view                0.0
# condition           4.0
# sqft_above       2280.0
# sqft_basement       0.0
# yr_built         2001.0
# yr_renovated        0.0
# Name: 818, dtype: float64

# %%
yeniEv = scaler.transform(yeniEv.values.reshape(-1,12))

# %%
model.predict(yeniEv)
# Out:
# array([[548043.06]], dtype=float32)
